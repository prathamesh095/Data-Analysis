# %% [markdown]
# # **Speaker Insights Using TED Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from plotly.subplots import make_subplots
import datetime as dt

# %% [markdown]
# ### **1) Loading Dataset**

# %%
df = pd.read_csv('ted_data.csv')
df.sample(5)
# Out:
#                                             title               author  \
# 781   The greatest mathematician that never lived         Pratik Aghor
# 1207  Why archaeology needs to transcend borders       Ella Al-Shamahi
# 1375      A vision for the future of Sierra Leone     Julius Maada Bio
# 146               Are locust plagues unstoppable?  Jeffrey A. Lockwood
# 1218        How motivation can fix public systems     Abhishek Gopalka
#
#                 date    views  likes  \
# 781        July 2020  2300000  70000
# 1207      April 2016    37000   1100
# 1375      April 2019  1800000  55000
# 146    November 2021   475000  14000
# 1218  September 2019  2000000  61000
#
#                                                    link
# 781   https://ted.com/talks/pratik_aghor_the_greates...
# 1207  https://ted.com/talks/ella_al_shamahi_why_arch...
# 1375  https://ted.com/talks/julius_maada_bio_a_visio...
# 146   https://ted.com/talks/jeffrey_a_lockwood_are_l...
# 1218  https://ted.com/talks/abhishek_gopalka_how_mot...

# %% [markdown]
# ### **2) Basic Information about data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df.describe(exclude=['object']) # Exclude columns with 'object' dtype
# Out:
#               views         likes
# count  5.440000e+03  5.440000e+03
# mean   2.061576e+06  6.260762e+04
# std    3.567098e+06  1.076468e+05
# min    5.320000e+02  1.500000e+01
# 25%    6.707500e+05  2.000000e+04
# 50%    1.300000e+06  4.050000e+04
# 75%    2.100000e+06  6.500000e+04
# max    7.200000e+07  2.100000e+06

# %%
df.isna().sum() #checking null values
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df.duplicated().sum() #checking dublicate values
# Out:
# 0

# %% [markdown]
# ## **3) Exploratory Data Analysis**
#
# #### **3.1) Finding the most popular TED talks :**

# %%
#adding views and likes to get popularity score
df['popularity_score'] = df['views'] + df['likes']

# Sort by popularity score and get the top 10
popular_ted = df[['title', 'popularity_score']].sort_values(by='popularity_score',
                                                            ascending=False).head(10).style.background_gradient(cmap='PuBuGn')
popular_ted
# Out:
# <style type="text/css">
# #T_6d417_row0_col1 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_6d417_row1_col1 {
#   background-color: #027e83;
#   color: #f1f1f1;
# }
# #T_6d417_row2_col1 {
#   background-color: #2b8db5;
#   color: #f1f1f1;
# }
# #T_6d417_row3_col1 {
#   background-color: #4f9dc8;
#   color: #f1f1f1;
# }
# #T_6d417_row4_col1 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_6d417_row5_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_6d417_row6_col1, #T_6d417_row7_col1 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_6d417_row8_col1 {
#   background-color: #f2e9f3;
#   color: #000000;
# }
# #T_6d417_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_6d417">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d417_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_6d417_level0_col1" class="col_heading level0 col1" >popularity_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d417_level0_row0" class="row_heading level0 row0" >5436</th>
#       <td id="T_6d417_row0_col0" class="data row0 col0" >Do schools kill creativity?</td>
#       <td id="T_6d417_row0_col1" class="data row0 col1" >74100000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row1" class="row_heading level0 row1" >4084</th>
#       <td id="T_6d417_row1_col0" class="data row1 col0" >Your body language may shape who you are</td>
#       <td id="T_6d417_row1_col1" class="data row1 col1" >65900000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row2" class="row_heading level0 row2" >2958</th>
#       <td id="T_6d417_row2_col0" class="data row2 col0" >Inside the mind of a master procrastinator</td>
#       <td id="T_6d417_row2_col1" class="data row2 col1" >61800000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row3" class="row_heading level0 row3" >4765</th>
#       <td id="T_6d417_row3_col0" class="data row3 col0" >How great leaders inspire action</td>
#       <td id="T_6d417_row3_col1" class="data row3 col1" >58700000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row4" class="row_heading level0 row4" >4605</th>
#       <td id="T_6d417_row4_col0" class="data row4 col0" >The power of vulnerability</td>
#       <td id="T_6d417_row4_col1" class="data row4 col1" >57700000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row5" class="row_heading level0 row5" >3504</th>
#       <td id="T_6d417_row5_col0" class="data row5 col0" >How to speak so that people want to listen</td>
#       <td id="T_6d417_row5_col1" class="data row5 col1" >50400000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row6" class="row_heading level0 row6" >2168</th>
#       <td id="T_6d417_row6_col0" class="data row6 col0" >My philosophy for a happy life</td>
#       <td id="T_6d417_row6_col1" class="data row6 col1" >44300000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row7" class="row_heading level0 row7" >3251</th>
#       <td id="T_6d417_row7_col0" class="data row7 col0" >The next outbreak? We're not ready</td>
#       <td id="T_6d417_row7_col1" class="data row7 col1" >44300000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row8" class="row_heading level0 row8" >3017</th>
#       <td id="T_6d417_row8_col0" class="data row8 col0" >What makes a good life? Lessons from the longest study on happiness</td>
#       <td id="T_6d417_row8_col1" class="data row8 col1" >42200000</td>
#     </tr>
#     <tr>
#       <th id="T_6d417_level0_row9" class="row_heading level0 row9" >3994</th>
#       <td id="T_6d417_row9_col0" class="data row9 col0" >Looks aren't everything. Believe me, I'm a model.</td>
#       <td id="T_6d417_row9_col1" class="data row9 col1" >39100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate a popularity score based on views and likes
df['popularity_score'] = df['views'] + df['likes']

# Sort by popularity score and get the top 10
popular_ted = df[['title', 'popularity_score']].sort_values(by='popularity_score', ascending=False).head(10)

# Visualization
fig = px.bar(x=popular_ted['popularity_score'], y=popular_ted["title"])
fig.update_layout(title_text='Top 10 TED Talks based on Popularity Score', xaxis_title="Popularity Score", yaxis_title="Title")
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
fig.show()

# %% [markdown]
# #### **3.2) Finding the most popular TED talks Speaker (in terms of number of talks)**

# %%
#top 10 Popular speaker In terms of likes
popular_speaker= df[['author','likes']].sort_values(by='likes', ascending=False).head(10).style.background_gradient(cmap='PuBuGn')
popular_speaker
# Out:
# <style type="text/css">
# #T_4012e_row0_col1 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_4012e_row1_col1 {
#   background-color: #027976;
#   color: #f1f1f1;
# }
# #T_4012e_row2_col1 {
#   background-color: #16879f;
#   color: #f1f1f1;
# }
# #T_4012e_row3_col1, #T_4012e_row4_col1 {
#   background-color: #4095c3;
#   color: #f1f1f1;
# }
# #T_4012e_row5_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_4012e_row6_col1, #T_4012e_row7_col1 {
#   background-color: #dbd8ea;
#   color: #000000;
# }
# #T_4012e_row8_col1 {
#   background-color: #f0e7f2;
#   color: #000000;
# }
# #T_4012e_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_4012e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4012e_level0_col0" class="col_heading level0 col0" >author</th>
#       <th id="T_4012e_level0_col1" class="col_heading level0 col1" >likes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4012e_level0_row0" class="row_heading level0 row0" >5436</th>
#       <td id="T_4012e_row0_col0" class="data row0 col0" >Sir Ken Robinson</td>
#       <td id="T_4012e_row0_col1" class="data row0 col1" >2100000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row1" class="row_heading level0 row1" >4084</th>
#       <td id="T_4012e_row1_col0" class="data row1 col0" >Amy Cuddy</td>
#       <td id="T_4012e_row1_col1" class="data row1 col1" >1900000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row2" class="row_heading level0 row2" >2958</th>
#       <td id="T_4012e_row2_col0" class="data row2 col0" >Tim Urban</td>
#       <td id="T_4012e_row2_col1" class="data row2 col1" >1800000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row3" class="row_heading level0 row3" >4605</th>
#       <td id="T_4012e_row3_col0" class="data row3 col0" >Brené Brown</td>
#       <td id="T_4012e_row3_col1" class="data row3 col1" >1700000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row4" class="row_heading level0 row4" >4765</th>
#       <td id="T_4012e_row4_col0" class="data row4 col0" >Simon Sinek</td>
#       <td id="T_4012e_row4_col1" class="data row4 col1" >1700000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row5" class="row_heading level0 row5" >3504</th>
#       <td id="T_4012e_row5_col0" class="data row5 col0" >Julian Treasure</td>
#       <td id="T_4012e_row5_col1" class="data row5 col1" >1400000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row6" class="row_heading level0 row6" >2168</th>
#       <td id="T_4012e_row6_col0" class="data row6 col0" >Sam Berns</td>
#       <td id="T_4012e_row6_col1" class="data row6 col1" >1300000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row7" class="row_heading level0 row7" >3251</th>
#       <td id="T_4012e_row7_col0" class="data row7 col0" >Bill Gates</td>
#       <td id="T_4012e_row7_col1" class="data row7 col1" >1300000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row8" class="row_heading level0 row8" >3017</th>
#       <td id="T_4012e_row8_col0" class="data row8 col0" >Robert Waldinger</td>
#       <td id="T_4012e_row8_col1" class="data row8 col1" >1200000</td>
#     </tr>
#     <tr>
#       <th id="T_4012e_level0_row9" class="row_heading level0 row9" >4990</th>
#       <td id="T_4012e_row9_col0" class="data row9 col0" >Mary Roach</td>
#       <td id="T_4012e_row9_col1" class="data row9 col1" >1100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating the dataframe
popular_speaker = df[['author','likes']].sort_values(by='likes', ascending=False).head(10)

# Visualization
fig = px.histogram(popular_speaker, x='likes', y='author',
                   color='author',
                   color_discrete_sequence=px.colors.qualitative.Set3)  # Use of predefined color sequence
fig.update_layout(title_text='Top 10 TED Talks based on number of views',
                  xaxis_title="Views", yaxis_title="Title")
fig.update_traces(marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
fig.show()

# %% [markdown]
# #### **3.3) Month-wise Analysis of TED talk frequency**

# %%
# Creating new columns
df['Published_year'] = pd.to_datetime(df['date']).dt.year            #year
df['Published_month'] = pd.to_datetime(df['date']).dt.month          #month name
df['Published_day'] = pd.to_datetime(df['date']).dt.day              #day

# %%
#dropping date column as we have extrated year , month and day and created new column
df.drop('date' , inplace=True , axis=1)

# %%
# getting number of titles in each month
month_wise = pd.DataFrame(data=df.groupby(['Published_month'])['title'].count()).reset_index()
month_wise
# Out:
#     Published_month  title
# 0                 1    147
# 1                 2    725
# 2                 3    580
# 3                 4    576
# 4                 5    322
# 5                 6    493
# 6                 7    446
# 7                 8    200
# 8                 9    349
# 9                10    585
# 10               11    682
# 11               12    335

# %%
fig = px.line(month_wise , x='Published_month' , y='title' , title='Month-wise Analysis of TED talk frequency')
fig.update_layout(xaxis_title='Month', yaxis_title='Number of Talks')
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.6 )
fig.show()

# %% [markdown]
# #### **3.4) Year-wise Analysis of TED talk frequency**

# %%
# getting the count of titles in each year and creating a dataFrame
year_wise = pd.DataFrame(data=df.groupby(['Published_year'] )['title'].count()).reset_index()
year_wise.head()
# Out:
#    Published_year  title
# 0            1970      2
# 1            1972      1
# 2            1983      1
# 3            1984      1
# 4            1990      1

# %%
fig = px.line(year_wise , x='Published_year' , y='title' , title='Year-wise Analysis of TED talk frequency')
fig.update_layout(xaxis_title='Year', yaxis_title='Number of Talks')
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.6 )
fig.show()

# %% [markdown]
# #### **3.5) Finding TED talks of your favorite Author**

# %%
# function to find your favorite talk
def fav_author(df,author):

  """
  df = provided dataset
  author = provide your fav author
  """

  df = df[df['author'] == author]

  if not df.empty:
    return df[['title' ,'author' ]]
  else:
    return 'No Author found'

# %%
# input your favorite author
author = input('Enter your favorite author')
#function
fav_author(df , author)
# Out:
#                                                   title      author
# 403   The innovations we need to avoid a climate dis...  Bill Gates
# 789         How the pandemic will shape the near future  Bill Gates
# 952     How we must respond to the coronavirus pandemic  Bill Gates
# 3251                 The next outbreak? We're not ready  Bill Gates
# 3878                        Teachers need real feedback  Bill Gates
# 4560          How state budgets are breaking US schools  Bill Gates
# 4824                                Innovating to zero!  Bill Gates
# 5062                   Mosquitos, malaria and education  Bill Gates

# %% [markdown]
# #### **3.6) Finding TED talks with the best view to like ratio**

# %%
## Finding TED talks with the best view to like ratio
ratio = df['views'] / df['likes']  #ratio

# %%
#plotting scatter plot views vs like
fig = px.scatter(df , x='views' , y='likes' , color=ratio , title='Views vs. Likes with Ratio as Color',
                 size='views', size_max=50)
fig.update_layout(xaxis_title='Views', yaxis_title='Likes')
fig.show()

# %% [markdown]
# #### **3.7) Finding TED talks based on tags (like climate)**

# %%
## creating a function
def tags(tag):
  # Convert the 'title' column to lowercase for case-insensitive matching
  # converting the tags to lower case for case-insensitive matching
  tag = tag.lower()
  # Filter the DataFrame based on the tag
  filtered_df = df[df['title'].str.lower().str.contains(tag)]

  if not filtered_df.empty:
    return filtered_df
  else:
    return 'No talk found'

# %%
tag = input('Enter tour favorite tag : ')
tags(tag)
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 17              The ocean's ingenious climate solutions           Susan Ruffo
# 18    How we're reducing the climate impact of elect...              Tim Dunn
# 34    How to boost nature-based solutions to climate...         Zac Goldsmith
# ...                                                 ...                   ...
# 4892              The science behind a climate headline           Rachel Pike
# 5226                 New thinking on the climate crisis               Al Gore
# 5280  A critical look at geoengineering against clim...           David Keith
# 5389       Global priorities bigger than climate change         Bjorn Lomborg
# 5439                        Averting the climate crisis               Al Gore
#
#         views   likes                                               link  \
# 0      404000   12000  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 3      427000   12000  https://ted.com/talks/james_k_thornton_why_is_...
# 17     522000   15000  https://ted.com/talks/susan_ruffo_the_ocean_s_...
# 18      96000    2900  https://ted.com/talks/tim_dunn_how_we_re_reduc...
# 34      30000     913  https://ted.com/talks/zac_goldsmith_how_to_boo...
# ...       ...     ...                                                ...
# 4892  1000000   31000  https://ted.com/talks/rachel_pike_the_science_...
# 5226  2200000   68000  https://ted.com/talks/al_gore_new_thinking_on_...
# 5280  1400000   44000  https://ted.com/talks/david_keith_a_critical_l...
# 5389  1700000   53000  https://ted.com/talks/bjorn_lomborg_global_pri...
# 5439  3600000  109000  https://ted.com/talks/al_gore_averting_the_cli...
#
#       popularity_score  Published_year  Published_month  Published_day
# 0               416000            2021               12              1
# 3               439000            2021               10              1
# 17              537000            2021               10              1
# 18               98900            2022                2              1
# 34               30913            2021               10              1
# ...                ...             ...              ...            ...
# 4892           1031000            2009                7              1
# 5226           2268000            2008                3              1
# 5280           1444000            2007                9              1
# 5389           1753000            2005                2              1
# 5439           3709000            2006                2              1
#
# [92 rows x 9 columns]

# %% [markdown]
# #### **3.8) Finding the most popular TED talks Speaker (in terms of number of views) :**

# %%
author_views = df.groupby(df['author'])['views'].sum().reset_index()
author_views.sort_values(by='views' , ascending=False).head(20).style.background_gradient(cmap='PuBuGn')
# Out:
# <style type="text/css">
# #T_a8668_row0_col1 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_a8668_row1_col1 {
#   background-color: #97b8d8;
#   color: #000000;
# }
# #T_a8668_row2_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_a8668_row3_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_a8668_row4_col1 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_a8668_row5_col1, #T_a8668_row6_col1 {
#   background-color: #dcd8ea;
#   color: #000000;
# }
# #T_a8668_row7_col1 {
#   background-color: #e2dced;
#   color: #000000;
# }
# #T_a8668_row8_col1 {
#   background-color: #e9e0ef;
#   color: #000000;
# }
# #T_a8668_row9_col1 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_a8668_row10_col1 {
#   background-color: #f6edf6;
#   color: #000000;
# }
# #T_a8668_row11_col1 {
#   background-color: #f8f0f7;
#   color: #000000;
# }
# #T_a8668_row12_col1 {
#   background-color: #faf1f8;
#   color: #000000;
# }
# #T_a8668_row13_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_a8668_row14_col1, #T_a8668_row15_col1 {
#   background-color: #fcf4f9;
#   color: #000000;
# }
# #T_a8668_row16_col1, #T_a8668_row17_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a8668_row18_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a8668_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a8668">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8668_level0_col0" class="col_heading level0 col0" >author</th>
#       <th id="T_a8668_level0_col1" class="col_heading level0 col1" >views</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8668_level0_row0" class="row_heading level0 row0" >148</th>
#       <td id="T_a8668_row0_col0" class="data row0 col0" >Alex Gendler</td>
#       <td id="T_a8668_row0_col1" class="data row0 col1" >187196000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row1" class="row_heading level0 row1" >3902</th>
#       <td id="T_a8668_row1_col0" class="data row1 col0" >Sir Ken Robinson</td>
#       <td id="T_a8668_row1_col1" class="data row1 col1" >95654000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row2" class="row_heading level0 row2" >544</th>
#       <td id="T_a8668_row2_col0" class="data row2 col0" >Bill Gates</td>
#       <td id="T_a8668_row2_col1" class="data row2 col1" >77800000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row3" class="row_heading level0 row3" >3895</th>
#       <td id="T_a8668_row3_col0" class="data row3 col0" >Simon Sinek</td>
#       <td id="T_a8668_row3_col1" class="data row3 col1" >74800000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row4" class="row_heading level0 row4" >594</th>
#       <td id="T_a8668_row4_col0" class="data row4 col0" >Brené Brown</td>
#       <td id="T_a8668_row4_col1" class="data row4 col1" >72000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row5" class="row_heading level0 row5" >2240</th>
#       <td id="T_a8668_row5_col0" class="data row5 col0" >Julian Treasure</td>
#       <td id="T_a8668_row5_col1" class="data row5 col1" >64300000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row6" class="row_heading level0 row6" >244</th>
#       <td id="T_a8668_row6_col0" class="data row6 col0" >Amy Cuddy</td>
#       <td id="T_a8668_row6_col1" class="data row6 col1" >64000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row7" class="row_heading level0 row7" >4184</th>
#       <td id="T_a8668_row7_col0" class="data row7 col0" >Tim Urban</td>
#       <td id="T_a8668_row7_col1" class="data row7 col1" >60000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row8" class="row_heading level0 row8" >1781</th>
#       <td id="T_a8668_row8_col0" class="data row8 col0" >Iseult Gillespie</td>
#       <td id="T_a8668_row8_col1" class="data row8 col1" >54998000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row9" class="row_heading level0 row9" >2914</th>
#       <td id="T_a8668_row9_col0" class="data row9 col0" >Mia Nacamulli</td>
#       <td id="T_a8668_row9_col1" class="data row9 col1" >44174000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row10" class="row_heading level0 row10" >3696</th>
#       <td id="T_a8668_row10_col0" class="data row10 col0" >Sam Berns</td>
#       <td id="T_a8668_row10_col1" class="data row10 col1" >43000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row11" class="row_heading level0 row11" >3589</th>
#       <td id="T_a8668_row11_col0" class="data row11 col0" >Robert Waldinger</td>
#       <td id="T_a8668_row11_col1" class="data row11 col1" >41000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row12" class="row_heading level0 row12" >1403</th>
#       <td id="T_a8668_row12_col0" class="data row12 col0" >Esther Perel</td>
#       <td id="T_a8668_row12_col1" class="data row12 col1" >39400000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row13" class="row_heading level0 row13" >649</th>
#       <td id="T_a8668_row13_col0" class="data row13 col0" >Cameron Russell</td>
#       <td id="T_a8668_row13_col1" class="data row13 col1" >38000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row14" class="row_heading level0 row14" >2819</th>
#       <td id="T_a8668_row14_col0" class="data row14 col0" >Mary Roach</td>
#       <td id="T_a8668_row14_col1" class="data row14 col1" >37000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row15" class="row_heading level0 row15" >1604</th>
#       <td id="T_a8668_row15_col0" class="data row15 col0" >Graham Shaw</td>
#       <td id="T_a8668_row15_col1" class="data row15 col1" >37000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row16" class="row_heading level0 row16" >1655</th>
#       <td id="T_a8668_row16_col0" class="data row16 col0" >Hans Rosling</td>
#       <td id="T_a8668_row16_col1" class="data row16 col1" >36255000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row17" class="row_heading level0 row17" >1311</th>
#       <td id="T_a8668_row17_col0" class="data row17 col0" >Elon Musk</td>
#       <td id="T_a8668_row17_col1" class="data row17 col1" >35800000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row18" class="row_heading level0 row18" >766</th>
#       <td id="T_a8668_row18_col0" class="data row18 col0" >Chimamanda Ngozi Adichie</td>
#       <td id="T_a8668_row18_col1" class="data row18 col1" >34800000</td>
#     </tr>
#     <tr>
#       <th id="T_a8668_level0_row19" class="row_heading level0 row19" >4217</th>
#       <td id="T_a8668_row19_col0" class="data row19 col0" >Tom Thum</td>
#       <td id="T_a8668_row19_col1" class="data row19 col1" >34000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# getting only top 20 speakers
author_views = author_views.sort_values(by='views', ascending=False).head(15)

# plotting bar-chart

fig = px.bar(author_views , x='author' , y='views' , title='Top 20 TED talks based on number of views',
             color="author",
             color_discrete_sequence=px.colors.qualitative.Set2)
fig.update_layout(xaxis_title='Author' , yaxis_title='Views')
fig.update_traces(marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
fig.show()
